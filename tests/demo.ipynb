# %% [markdown]
# # Test for the cnn module

# %% [markdown]
# Source: https://scikit-learn.org/stable/auto_examples/cluster/plot_cluster_comparison.html
#
# The test consists of six model data sets.

# %% [markdown]
# First import the module.

# %%
import cnn

# %% [markdown]
# Other import:

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

# %%
from matplotlib import cm
rcParams['figure.figsize'] = 6.50128*0.5, 6.50128*0.5*0.618*1.1
dpi = 300
rcParams['figure.dpi'] =  dpi
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = 'Latin Modern Sans'

# %% [markdown]
# Set how many data points should be generated and a random seed.

# %%
np.random.seed(0)
n_samples = 2000

# %% [markdown]
# Then we can generate the test sets.

# %%
noisy_circles, _ = datasets.make_circles(n_samples=n_samples,
                                         factor=.5,
                                         noise=.05)

noisy_moons, _ = datasets.make_moons(n_samples=n_samples,
                                     noise=.05)

blobs, _ = datasets.make_blobs(n_samples=n_samples,
                            random_state=8)

no_structure = np.random.rand(n_samples, 2)

random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples,
                           random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = X_aniso

varied, _ = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)

# %% [markdown]
# Set the cluster parameters:

# %%
testsets = [
    ('circles', noisy_circles, {'radius_cutoff': 0.5, 'cnn_cutoff': 20,
                     'member_cutoff': 100, 'max_clusters': None}),
    ('moons', noisy_moons, {'radius_cutoff': 0.5, 'cnn_cutoff': 20,
                     'member_cutoff': 1, 'max_clusters': None}),
    ('varied', varied, {'radius_cutoff': 0.28, 'cnn_cutoff': 20,
                     'member_cutoff': 20, 'max_clusters': None}),
    ('aniso', aniso, {'radius_cutoff': 0.29, 'cnn_cutoff': 30,
                     'member_cutoff': 5, 'max_clusters': None}),
    ('blobs', blobs, {'radius_cutoff': 0.4, 'cnn_cutoff': 20,
                     'member_cutoff': 1, 'max_clusters': None}),
    ('None', no_structure, {'radius_cutoff': 0.5, 'cnn_cutoff': 20,
                     'member_cutoff': 1, 'max_clusters': None}),
    ]

# %% [markdown]
# And take a look at the sets:

# %%
fig, ax = plt.subplots(2, 3)
Ax = ax.flatten()

for count, (testset_name, testset, *_) in enumerate(testsets):
    testset = StandardScaler().fit_transform(testset)
    axes = Ax[count]
    axes.plot(testset[:, 0], testset[:, 1], '.')
    axes.set_xticks(())
    axes.set_yticks(())
    axes.set_xlim(-2.5, 2.5)
    axes.set_ylim(-2.5, 2.5)
    axes.set_title(f'{testset_name}', fontsize=10, pad=2)

# %% [markdown]
# Next we specify the cluster parameters used for each set.

# %%
fig, ax = plt.subplots(2, 3)
Ax = ax.flatten()

for count, (testset_name, testset, params) in enumerate(testsets):
    testset = StandardScaler().fit_transform(testset)
    
    cobj = cnn.CNN(train=testset)
    # cobj.dist()
    # cobj.dist_hist()
    cobj.fit(radius_cutoff=params['radius_cutoff'],
                 cnn_cutoff=params['cnn_cutoff'],
                 member_cutoff=params['member_cutoff'],
                 max_clusters=params['max_clusters'])

    colors = np.array(list(islice(cycle(['#000000', '#396ab1', '#da7c30',
                                         '#3e9651', '#cc2529', '#535154',
                                         '#6b4c9a', '#922428', '#948b3d']),
                                  int(max(cobj.train_labels) + 1))))

    axes = Ax[count]
    axes.scatter(testset[:, 0], testset[:, 1],
                 s=10,
                 color=colors[cobj.train_labels])
    axes.set_xticks(())
    axes.set_yticks(())
    axes.set_xlim(-2.5, 2.5)
    axes.set_ylim(-2.5, 2.5)
    axes.set_title(f'{testset_name}', fontsize=10, pad=2)
    
plt.show()
plt.close()
# Out:
# Configuration file found in /home/janjoswig
# Calculating nxn distance matrix for 2000 points
# Execution time for call of dist(): 0 hours, 0 minutes, 0.0218 seconds
# Execution time for call of fit(): 0 hours, 0 minutes, 0.3681 seconds
# recording: ...
# points               2000
# radius_cutoff         0.5
# cnn_cutoff             20
# member_cutoff         100
# max_clusters         None
# n_clusters              2
# largest               0.5
# noise                   0
# time             0.368072
# dtype: object
# Configuration file found in /home/janjoswig
# Calculating nxn distance matrix for 2000 points
# Execution time for call of dist(): 0 hours, 0 minutes, 0.0186 seconds
# Execution time for call of fit(): 0 hours, 0 minutes, 0.4695 seconds
# recording: ...
# points               2000
# radius_cutoff         0.5
# cnn_cutoff             20
# member_cutoff           1
# max_clusters         None
# n_clusters              2
# largest               0.5
# noise                   0
# time             0.469535
# dtype: object
# Configuration file found in /home/janjoswig
# Calculating nxn distance matrix for 2000 points
# Execution time for call of dist(): 0 hours, 0 minutes, 0.0174 seconds
# Execution time for call of fit(): 0 hours, 0 minutes, 0.4935 seconds
# recording: ...
# points               2000
# radius_cutoff        0.28
# cnn_cutoff             20
# member_cutoff          20
# max_clusters         None
# n_clusters              3
# largest             0.338
# noise              0.1145
# time             0.493505
# dtype: object
# Configuration file found in /home/janjoswig
# Calculating nxn distance matrix for 2000 points
# Execution time for call of dist(): 0 hours, 0 minutes, 0.0175 seconds
# Execution time for call of fit(): 0 hours, 0 minutes, 0.4226 seconds
# recording: ...
# points               2000
# radius_cutoff        0.29
# cnn_cutoff             30
# member_cutoff           5
# max_clusters         None
# n_clusters              3
# largest            0.3185
# noise                0.05
# time             0.422612
# dtype: object
# Configuration file found in /home/janjoswig
# Calculating nxn distance matrix for 2000 points
# Execution time for call of dist(): 0 hours, 0 minutes, 0.0174 seconds
# Execution time for call of fit(): 0 hours, 0 minutes, 0.7951 seconds
# recording: ...
# points               2000
# radius_cutoff         0.4
# cnn_cutoff             20
# member_cutoff           1
# max_clusters         None
# n_clusters              3
# largest            0.3335
# noise              0.0005
# time             0.795094
# dtype: object
# Configuration file found in /home/janjoswig
# Calculating nxn distance matrix for 2000 points
# Execution time for call of dist(): 0 hours, 0 minutes, 0.0174 seconds
# Execution time for call of fit(): 0 hours, 0 minutes, 0.2943 seconds
# recording: ...
# points               2000
# radius_cutoff         0.5
# cnn_cutoff             20
# member_cutoff           1
# max_clusters         None
# n_clusters              1
# largest                 1
# noise                   0
# time             0.294261
# dtype: object
